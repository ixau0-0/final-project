# %% [markdown]
# <a href="https://colab.research.google.com/github/ixau0-0/final-project/blob/main/requirment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
python_package="""" panads
seaborn
numpy
matplotlib
sklearn"""
with open("requirment.txt","w") as f:
  f.write(python_package)
